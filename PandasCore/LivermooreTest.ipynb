# %%
import pandas 
import pandas_indicators
from pandas_datareader import data, wb, yahoo
import datetime
start=datetime.datetime(2001,1,1)
end=datetime.datetime(2017,4,5)
# %matplotlib inline

# %%
dir(pandas_indicators)
# Out:
# ['ACCDIST',
#  'ADX',
#  'ATR',
#  'BBANDS',
#  'CCI',
#  'COPP',
#  'Chaikin',
#  'DONCH',
#  'EMA',
#  'EOM',
#  'FORCE',
#  'KELCH',
#  'KST',
#  'LiverMoore',
#  'MA',
#  'MACD',
#  'MFI',
#  'MOM',
#  'MassI',
#  'OBV',
#  'PPSR',
#  'ROC',
#  'ROC_pandas',
#  'RSI',
#  'STDDEV',
#  'STO',
#  'STOK',
#  'TRIX',
#  'TR_pandas',
#  'TSI',
#  'ULTOSC',
#  'Vortex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'pd']

# %%
DF=data.DataReader('LMT','yahoo',start,end).reset_index()
pandas_indicators.LiverMoore(DF,14)['LiverMoore_Key'].plot()
# Out:
# /home/lc1bfrbl/Development/PythonTrading/NewStructure/PandasCore/pandas_indicators.py:62: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(ignore_na=False,min_periods=14,adjust=True,span=14).mean()
#   ATR = pd.Series(pd.ewma(TR_s, span = n, min_periods = n), name = 'ATR_' + str(n))

# %%
pandas_indicators.LiverMoore(DF,14)
# Out:
# /home/lc1bfrbl/Development/PythonTrading/NewStructure/PandasCore/pandas_indicators.py:62: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(ignore_na=False,min_periods=14,adjust=True,span=14).mean()
#   ATR = pd.Series(pd.ewma(TR_s, span = n, min_periods = n), name = 'ATR_' + str(n))
#            Date        Open        High         Low       Close   Volume  \
# 0    2001-01-02   33.950001   34.750000   33.709999   34.099998  1625000
# 1    2001-01-03   33.500000   34.500000   33.150002   33.650002  2071200
# 2    2001-01-04   33.400002   33.799999   32.500000   33.400002  2207400
# 3    2001-01-05   33.000000   33.119999   32.400002   32.849998   669000
# 4    2001-01-08   32.599998   33.650002   32.400002   32.910000   729700
# 5    2001-01-09   32.250000   34.500000   32.250000   34.240002  1046700
# 6    2001-01-10   33.599998   34.189999   33.000000   33.770000  1042000
# ...
